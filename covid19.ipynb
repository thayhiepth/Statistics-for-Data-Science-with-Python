# %%
#Lấy dữ liệu COVID từ trang web tạo thành file Data Excel,
#Tác giả:  Trịnh Huy Hiệp

# %%
#Nhập các thư viện cần thiết ( đã cài ở CMD các thư viện: pandas, numpy, matplotlib, scipy, math)
#pip install pandas
#pip install numpy
#pip install matplotlib
#pip install scipy
#pip install math

# %% [markdown]
# Cài đặt thư viện Requests:

# %%
pip install requests

# %% [markdown]
# Cài đặt thư viện LXML và các thư viện liên quan

# %%
pip install lxml

# %%
pip install html5lib

# %%
pip install beautifulSoup4

# %% [markdown]
# #Dùng code để lấy dữ liệu từ trang web

# %%
#Extracts data in table tables from website
import pandas as pd
import requests
from bs4 import BeautifulSoup
url = 'https://www.worldometers.info/coronavirus/'
req = requests.get(url)
page = BeautifulSoup(req.content, 'html.parser')
table = page.find_all('table',id="main_table_countries_today")[0]
print(table)
df = pd.read_html(str(table), displayed_only=False)[0]
covid19_data=df

# %% [markdown]
# #Mở xem dữ liệu đã lấy về

# %%
covid19_data
# Out:
#       # Country, Other  Total Cases  New Cases  Total Deaths  New Deaths  \
# 0   NaN  North America    131889132        NaN     1695941.0         NaN
# 1   NaN           Asia    221500265        NaN     1553662.0         NaN
# 2   NaN         Europe    253406198        NaN     2101824.0         NaN
# 3   NaN  South America     70200879        NaN     1367332.0         NaN
# 4   NaN        Oceania     14895771        NaN       33015.0         NaN
# ..   ..            ...          ...        ...           ...         ...
# 242 NaN         Total:     70200879        NaN     1367332.0         NaN
# 243 NaN         Total:     14895771        NaN       33015.0         NaN
# 244 NaN         Total:     12860924        NaN      258892.0         NaN
# 245 NaN         Total:          721        NaN          15.0         NaN
# 246 NaN         Total:    704753890        0.0     7010681.0         0.0
#
#      Total Recovered  New Recovered  Active Cases  Serious, Critical  ...  \
# ...

# %% [markdown]
# #Lưu dữ liệu về 1 file Excel

# %%
pip install openpyxl

# %%
covid19_data.to_excel( 'D:/covid19.xlsx')

# %% [markdown]
# #Hoặc thành 1 file CSV:

# %%
covid19_data.to_csv( 'D:/covid19.csv')
